# %% [markdown]
# <a href="https://colab.research.google.com/github/123Osama/Markopolo.ai-Intern-Assesment-Project/blob/main/Intern_assesment(winequality_white).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import all necessary libraries

import pandas as pd
import numpy as np

#for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Laod data using pandas
df = pd.read_csv("/content/drive/MyDrive/Intern at Markopolo.ai/winequality-white.csv")
df.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...

# %%
df.tail()
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...

# %%
df.shape
# Out:
# (4898, 1)

# %%
#Separate the values in this one column and convert it into 12 different columns
df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                  'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
                  'pH', 'sulphates', 'alcohol', 'quality']] = df['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'].str.split(";",expand=True)

# %%
#Check new created columns
df.head(5)
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"  \
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
#
#   fixed acidity volatile acidity citric acid residual sugar chlorides  \
# 0             7             0.27        0.36           20.7     0.045
# 1           6.3              0.3        0.34            1.6     0.049
# 2           8.1             0.28         0.4            6.9      0.05
# 3           7.2             0.23        0.32            8.5     0.058
# 4           7.2             0.23        0.32            8.5     0.058
#
#   free sulfur dioxide total sulfur dioxide density    pH sulphates alcohol  \
# ...

# %%
#Delete the previous column from index 0
df.drop(df.columns[0], axis=1, inplace=True)
df.head()
# Out:
#   fixed acidity volatile acidity citric acid residual sugar chlorides  \
# 0             7             0.27        0.36           20.7     0.045
# 1           6.3              0.3        0.34            1.6     0.049
# 2           8.1             0.28         0.4            6.9      0.05
# 3           7.2             0.23        0.32            8.5     0.058
# 4           7.2             0.23        0.32            8.5     0.058
#
#   free sulfur dioxide total sulfur dioxide density    pH sulphates alcohol  \
# 0                  45                  170   1.001     3      0.45     8.8
# 1                  14                  132   0.994   3.3      0.49     9.5
# 2                  30                   97  0.9951  3.26      0.44    10.1
# 3                  47                  186  0.9956  3.19       0.4     9.9
# 4                  47                  186  0.9956  3.19       0.4     9.9
#
#   quality
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6

# %%
df.describe()
# Out:
#        fixed acidity volatile acidity citric acid residual sugar chlorides  \
# count           4898             4898        4898           4898      4898
# unique            68              125          87            310       160
# top              6.8             0.28         0.3            1.2     0.044
# freq             308              263         307            187       201
#
#        free sulfur dioxide total sulfur dioxide density    pH sulphates  \
# count                 4898                 4898    4898  4898      4898
# unique                 132                  251     890   103        79
# top                     29                  111   0.992  3.14       0.5
# freq                   160                   69      64   172       249
#
#        alcohol quality
# count     4898    4898
# unique     104       7
# top        9.4       6
# freq       229    2198

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   object
#  1   volatile acidity      4898 non-null   object
#  2   citric acid           4898 non-null   object
#  3   residual sugar        4898 non-null   object
#  4   chlorides             4898 non-null   object
#  5   free sulfur dioxide   4898 non-null   object
#  6   total sulfur dioxide  4898 non-null   object
#  7   density               4898 non-null   object
#  8   pH                    4898 non-null   object
#  9   sulphates             4898 non-null   object
#  10  alcohol               4898 non-null   object
#  11  quality               4898 non-null   object
# dtypes: object(12)
# memory usage: 459.3+ KB

# %%
#remove duplicates from the dataframe
df = df.drop_duplicates()

#check the shape after removing the duplicates
df.shape
# Out:
# (3961, 12)

# %%
#check for missing values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#check unique values for each column for standarization

for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in {column}:")
    print(unique_values)
# Out:
# Unique values in fixed acidity:
# ['7' '6.3' '8.1' '7.2' '6.2' '8.6' '7.9' '6.6' '8.3' '7.4' '6.5' '6.4'
#  '6.8' '7.6' '6.9' '8.5' '5.8' '7.3' '6.7' '6' '7.1' '6.1' '7.5' '9.8'
#  '5.5' '5.9' '7.8' '5.7' '8.2' '5.6' '5.2' '8.4' '10.2' '7.7' '5.3' '5.4'
#  '9.1' '5' '8' '10' '5.1' '9.2' '9' '8.8' '8.7' '4.8' '10.3' '9.4' '9.6'
#  '9.3' '8.9' '9.7' '10.7' '14.2' '9.9' '9.5' '11.8' '4.6' '6.15' '4.5'
#  '7.15' '6.45' '4.2' '4.9' '4.7' '3.8' '4.4' '3.9']
# Unique values in volatile acidity:
# ['0.27' '0.3' '0.28' '0.23' '0.32' '0.22' '0.18' '0.16' '0.42' '0.17'
#  '0.48' '0.66' '0.34' '0.31' '0.26' '0.67' '0.25' '0.24' '0.14' '0.12'
#  '0.39' '0.33' '0.45' '0.46' '0.19' '0.2' '0.21' '0.38' '0.47' '0.35'
#  '0.54' '0.43' '0.44' '0.265' '0.36' '0.305' '0.13' '0.41' '0.485' '0.425'
#  '0.37' '0.255' '0.595' '0.29' '0.53' '0.15' '0.57' '0.4' '0.245' '0.685'
#  '0.495' '0.64' '0.52' '0.115' '0.58' '0.585' '0.59' '0.6' '0.55' '0.125'
# ...

# %%
#round the decimal points of some values of alcohol

df['alcohol'] = df['alcohol'].astype(float).round(1)
df['alcohol'].unique()
# Out:
# <ipython-input-73-163fa566c989>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['alcohol'] = df['alcohol'].astype(float).round(1)
# array([ 8.8,  9.5, 10.1,  9.9,  9.6, 11. , 12. ,  9.7, 10.8, 12.4, 11.4,
#        12.8, 11.3, 10.5,  9.3, 10. , 10.4, 11.6, 12.3, 10.2,  9. , 11.2,
#         8.6,  9.4,  9.8, 11.7, 10.9,  9.1,  8.9, 10.3, 12.6, 10.7, 12.7,
#        10.6,  9.2,  8.7, 11.5, 11.8, 12.1, 11.1,  8.5, 12.5, 11.9, 12.2,
#        12.9, 13.9, 14. , 13.5, 13.3, 13.2, 13.7, 13.4, 13. ,  8. , 13.1,
#        13.6,  8.4, 14.2, 13.8])

# %%
df['alcohol'].shape
# Out:
# (3961,)

# %%
#describe all the columns
for column in df.columns:
    description = df[column].describe()
    print(f"Description of {column}:")
    print(description)
# Out:
# Description of fixed acidity:
# count     3961
# unique      68
# top        6.8
# freq       241
# Name: fixed acidity, dtype: object
# Description of volatile acidity:
# count     3961
# unique     125
# top       0.28
# freq       213
# Name: volatile acidity, dtype: object
# Description of citric acid:
# count     3961
# unique      87
# top        0.3
# freq       239
# Name: citric acid, dtype: object
# Description of residual sugar:
# count     3961
# unique     310
# top        1.4
# freq       165
# Name: residual sugar, dtype: object
# Description of chlorides:
# count      3961
# unique      160
# top       0.036
# freq        165
# Name: chlorides, dtype: object
# Description of free sulfur dioxide:
# count     3961
# unique     132
# top         29
# freq       125
# Name: free sulfur dioxide, dtype: object
# Description of total sulfur dioxide:
# count     3961
# unique     251
# top        111
# freq        51
# Name: total sulfur dioxide, dtype: object
# ...

# %%
#convert object type data to numerical dtype
for col in df.columns:
    df[col] = df[col].astype(float)

# %%
#description of each column after converting into numerical dtype
for column in df.columns:
    description = df[column].describe()
    print(f"Description of {column}:")
    print(description)
# Out:
# Description of fixed acidity:
# count    3961.000000
# mean        6.839346
# std         0.866860
# min         3.800000
# 25%         6.300000
# 50%         6.800000
# 75%         7.300000
# max        14.200000
# Name: fixed acidity, dtype: float64
# Description of volatile acidity:
# count    3961.000000
# mean        0.280538
# std         0.103437
# min         0.080000
# 25%         0.210000
# 50%         0.260000
# 75%         0.330000
# max         1.100000
# Name: volatile acidity, dtype: float64
# Description of citric acid:
# count    3961.000000
# mean        0.334332
# std         0.122446
# min         0.000000
# 25%         0.270000
# 50%         0.320000
# 75%         0.390000
# max         1.660000
# Name: citric acid, dtype: float64
# Description of residual sugar:
# count    3961.000000
# mean        5.914819
# std         4.861646
# min         0.600000
# 25%         1.600000
# 50%         4.700000
# 75%         8.900000
# max        65.800000
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#Plot histogram to observe the distribution


#Define figure size
plt.figure(figsize=(20,12))

#Use subplot to plot all the 12 columns with 3 rows and 4 columns

#Subplot for "fixed acodity"
plt.subplot(3,4,1)
sns.histplot(df['fixed acidity'],kde=True)
plt.title("row=1, col=1, position=1")

#Subplot for "volatile acodity"
plt.subplot(3,4,2)
sns.histplot(df['volatile acidity'],kde=True)
plt.title("row=1, col=2, position=2")

#Subplot for "citric acid"
plt.subplot(3,4,3)
sns.histplot(df['citric acid'],kde=True)
plt.title("row=1, col=3, position=3")

#Subplot for "residual suger"
plt.subplot(3,4,4)
sns.histplot(df['residual sugar'],kde=True)
plt.title("row=1, col=4, position=4")

#Subplot for "chlorides"
plt.subplot(3,4,5)
sns.histplot(df['chlorides'],kde=True)
plt.title("row=2, col=1, position=5")

#Subplot for "free sulfur dioxide"
plt.subplot(3,4,6)
sns.histplot(df['free sulfur dioxide'],kde=True)
plt.title("row=2, col=2, position=6")

#Subplot for "total sulfur dioxide"
plt.subplot(3,4,7)
sns.histplot(df['total sulfur dioxide'],kde=True)
plt.title("row=2, col=3, position=7")

#Subplot for "density"
plt.subplot(3,4,8)
sns.histplot(df['density'],kde=True)
plt.title("row=2, col=4, position=8")

#Subplot for "pH"
plt.subplot(3,4,9)
sns.histplot(df['pH'],kde=True)
plt.title("row=3, col=1, position=9")

#Subplot for "sulphates"
plt.subplot(3,4,10)
sns.histplot(df['sulphates'],kde=True)
plt.title("row=3, col=2, position=10")

#Subplot for "alcohol"
plt.subplot(3,4,11)
sns.histplot(df['alcohol'],kde=True)
plt.title("row=3, col=3, position=11")

#Subplot for "quality"
plt.subplot(3,4,12)
sns.histplot(df['quality'],kde=True)
plt.title("row=3, col=4, position=12")

# Adjust the spacing between subplots
plt.tight_layout()

#Display the plots
plt.show()

# %%
#Plot boxplot to see the outliers

#Define figuresize
plt.figure(figsize=(20,12))

#Use subplot to plot all the 12 columns with 3 rows and 4 columns

#Subplot for "fixed acodity"
plt.subplot(3,4,1)
sns.boxplot(df['fixed acidity'])
plt.xlabel('fixed acidity')
plt.title("row=1, col=1, position=1")

#Subplot for "volatile acodity"
plt.subplot(3,4,2)
sns.boxplot(df['volatile acidity'])
plt.xlabel('volatile acidity')
plt.title("row=1, col=2, position=2")


#Subplot for "citric acid"
plt.subplot(3,4,3)
sns.boxplot(df['citric acid'])
plt.xlabel('citric acid')
plt.title("row=1, col=3, position=3")


#Subplot for "residual sugar"
plt.subplot(3,4,4)
sns.boxplot(df['residual sugar'])
plt.xlabel('residual sugar')
plt.title("row=1, col=4, position=4")

#Subplot for "chlorides"
plt.subplot(3,4,5)
sns.boxplot(df['chlorides'])
plt.xlabel('chlorides')
plt.title("row=2, col=1, position=5")


#Subplot for "free sulfur dioxide"
plt.subplot(3,4,6)
sns.boxplot(df['free sulfur dioxide'])
plt.xlabel('free sulfur dioxide')
plt.title("row=2, col=2, position=6")


#Subplot for "total sulfur dioxide"
plt.subplot(3,4,7)
sns.boxplot(df['total sulfur dioxide'])
plt.xlabel('total sulfur dioxide')
plt.title("row=2, col=3, position=7")


#Subplot for "density"
plt.subplot(3,4,8)
sns.boxplot(df['density'])
plt.xlabel('density')
plt.title("row=2, col=4, position=8")


#Subplot for "pH"
plt.subplot(3,4,9)
sns.boxplot(df['pH'])
plt.xlabel('pH')
plt.title("row=3, col=1, position=9")


#Subplot for "sulphates"
plt.subplot(3,4,10)
sns.boxplot(df['sulphates'])
plt.xlabel('sulphates')
plt.title("row=3, col=2, position=10")


#Subplot for "alcohol"
plt.subplot(3,4,11)
sns.boxplot(df['alcohol'])
plt.xlabel('alcohol')
plt.title("row=3, col=3, position=11")


#Subplot for "quality"
plt.subplot(3,4,12)
sns.boxplot(df['quality'])
plt.xlabel('quality')
plt.title("row=3, col=4, position=12")

# Adjust the spacing between subplots
plt.tight_layout()

#Display all plots
plt.show()

# %%
df.shape
# Out:
# (3961, 12)

# %%
#Handle outliers using IQR method with capping technique

# Assuming your dataset is in a DataFrame named 'df'

# Create a copy of the DataFrame
df_cleaned = df.copy()

# Iterate over each column
for column_name in df.columns:
    # Calculate the quartiles and interquartile range (IQR)
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1

    # Determine the upper and lower bounds for capping
    upper_bound = Q3 + 1.5 * IQR
    lower_bound = Q1 - 1.5 * IQR

    # Cap outliers using np.where()
    df_cleaned[column_name] = np.where(
        df_cleaned[column_name] > upper_bound,
        upper_bound,
        np.where(
            df_cleaned[column_name] < lower_bound,
            lower_bound,
            df_cleaned[column_name]
        )
    )

# Reset the index of the cleaned DataFrame
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
df_cleaned.shape
# Out:
# (3961, 12)

# %%
#Check boxplot again after removal of outliers

#Define figuresize
plt.figure(figsize=(20,12))

#Use subplot to plot all the 12 columns with 3 rows and 4 columns

#Subplot for "fixed acodity"
plt.subplot(3,4,1)
sns.boxplot(df_cleaned['fixed acidity'])
plt.xlabel('fixed acidity')
plt.title("row=1, col=1, position=1")

#Subplot for "volatile acodity"
plt.subplot(3,4,2)
sns.boxplot(df_cleaned['volatile acidity'])
plt.xlabel('volatile acidity')
plt.title("row=1, col=2, position=2")


#Subplot for "citric acid"
plt.subplot(3,4,3)
sns.boxplot(df_cleaned['citric acid'])
plt.xlabel('citric acid')
plt.title("row=1, col=3, position=3")


#Subplot for "residual sugar"
plt.subplot(3,4,4)
sns.boxplot(df_cleaned['residual sugar'])
plt.xlabel('residual sugar')
plt.title("row=1, col=4, position=4")

#Subplot for "chlorides"
plt.subplot(3,4,5)
sns.boxplot(df_cleaned['chlorides'])
plt.xlabel('chlorides')
plt.title("row=2, col=1, position=5")


#Subplot for "free sulfur dioxide"
plt.subplot(3,4,6)
sns.boxplot(df_cleaned['free sulfur dioxide'])
plt.xlabel('free sulfur dioxide')
plt.title("row=2, col=2, position=6")


#Subplot for "total sulfur dioxide"
plt.subplot(3,4,7)
sns.boxplot(df_cleaned['total sulfur dioxide'])
plt.xlabel('total sulfur dioxide')
plt.title("row=2, col=3, position=7")


#Subplot for "density"
plt.subplot(3,4,8)
sns.boxplot(df_cleaned['density'])
plt.xlabel('density')
plt.title("row=2, col=4, position=8")


#Subplot for "pH"
plt.subplot(3,4,9)
sns.boxplot(df_cleaned['pH'])
plt.xlabel('pH')
plt.title("row=3, col=1, position=9")


#Subplot for "sulphates"
plt.subplot(3,4,10)
sns.boxplot(df_cleaned['sulphates'])
plt.xlabel('sulphates')
plt.title("row=3, col=2, position=10")


#Subplot for "alcohol"
plt.subplot(3,4,11)
sns.boxplot(df_cleaned['alcohol'])
plt.xlabel('alcohol')
plt.title("row=3, col=3, position=11")


#Subplot for "quality"
plt.subplot(3,4,12)
sns.boxplot(df_cleaned['quality'])
plt.xlabel('quality')
plt.title("row=3, col=4, position=12")

# Adjust the spacing between subplots
plt.tight_layout()

#Display all plots
plt.show()

# %%
#Copy the dataframe into df_new
df_new=df_cleaned.copy()
df_new.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36           19.85      0.045
# 1            6.3              0.30         0.34            1.60      0.049
# 2            8.1              0.28         0.40            6.90      0.050
# 3            7.2              0.23         0.32            8.50      0.058
# 4            6.2              0.32         0.16            7.00      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality
# 0      8.8      6.0
# 1      9.5      6.0
# 2     10.1      6.0
# ...

# %% [markdown]
# #Visualization

# %% [markdown]
# ###Line plot

# %%
#Define the figure size
plt.figure(figsize=(20,12))

#Use subplot to plot all the 12 columns with 3 rows and 4 columns

#Subplot for "fixed acodity" vs "quality"
plt.subplot(3,4,1)
sns.lineplot(x = "fixed acidity", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "volatile acidity" vs "quality"
plt.subplot(3,4,2)
sns.lineplot(x = "volatile acidity", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "citric acid" vs "quality"
plt.subplot(3,4,3)
sns.lineplot(x = "citric acid", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "chlorides" vs "quality"
plt.subplot(3,4,4)
sns.lineplot(x = "chlorides", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "free sulfur dioxide" vs "quality"
plt.subplot(3,4,5)
sns.lineplot(x = "free sulfur dioxide", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "total sulfur dioxide" vs "quality"
plt.subplot(3,4,6)
sns.lineplot(x = "total sulfur dioxide", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "density" vs "quality"
plt.subplot(3,4,7)
sns.lineplot(x = "density", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "pH" vs "quality"
plt.subplot(3,4,8)
sns.lineplot(x = "pH", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "sulphates" vs "quality"
plt.subplot(3,4,9)
sns.lineplot(x = "sulphates", y = "quality",data=df_new)
sns.set(style='dark',)

#Subplot for "alcohol" vs "quality"
plt.subplot(3,4,10)
sns.lineplot(x = "alcohol", y = "quality",data=df_new)
sns.set(style='dark',)

# Adjust the spacing between subplots
plt.tight_layout()

#Display all plots
plt.show()

# %% [markdown]
# ###Bar chart

# %%
plt.figure(figsize=(4, 4))

# Create a bar chart for the output variable "quality"

quality_counts = df_new['quality'].value_counts()

plt.bar(quality_counts.index, quality_counts.values)
plt.xlabel('Quality')
plt.ylabel('Count')

# Adjust the spacing between subplots
plt.title('Bar Chart of Quality')

plt.show()

# %% [markdown]
# ###Pie chart

# %%
quality_counts = df['quality'].value_counts()

# Create a pie chart for output variable "quality"
plt.figure(figsize=(4, 4))
plt.pie(quality_counts.values, labels=quality_counts.index, autopct='%1.1f%%')
plt.title('Pie Chart of Quality')

# Adjust the spacing between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ###Scatterplot

# %%
# Create a figure with a specific size
plt.figure(figsize=(20, 16))

# Iterate over each column (except 'quality')
for i, column_name in enumerate(df_new.columns[:-1], 1):
    # Create a subplot for each column
    plt.subplot(3, 4, i)
    sns.scatterplot(x=column_name, y='quality', data=df_new)
    plt.xlabel(column_name)
    plt.ylabel('quality')
    plt.title(f'Scatter Plot: {column_name} vs quality')

# Adjust the spacing between subplots
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ###Heatmap

# %%
# Calculate the correlation matrix
correlation_matrix = df_new.corr()
print(correlation_matrix)

# Create a figure and axes
plt.figure(figsize=(10, 10))

# Generate the heatmap
sns.heatmap(correlation_matrix, annot=True, square=True,
            vmax=1.0, vmin=-1.0,
            cmap="RdYlGn")

# Set the title
plt.title('Correlation Matrix Heatmap')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90)

# Display the plot
plt.show()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.032292     0.315387
# volatile acidity          -0.032292          1.000000    -0.176368
# citric acid                0.315387         -0.176368     1.000000
# residual sugar             0.091681          0.093971     0.097803
# chlorides                  0.071459          0.050789     0.082766
# free sulfur dioxide       -0.052357         -0.103536     0.106307
# total sulfur dioxide       0.085230          0.112368     0.121467
# density                    0.275213          0.035557     0.157883
# pH                        -0.431857         -0.056120    -0.186586
# sulphates                 -0.015201         -0.028181     0.057906
# alcohol                   -0.110363          0.053430    -0.073203
# quality                   -0.117005         -0.188407     0.017844
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...
